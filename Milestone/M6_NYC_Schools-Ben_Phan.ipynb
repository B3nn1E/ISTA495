# %% [markdown]
# ![](https://upload.wikimedia.org/wikipedia/commons/b/b1/NYC_DOE_Logo.png)
#
# # Introduction
# Welcome to your first day as a newly minted analyst working for New York City’s Department of Education!
#
# You have been handed a CSV file containing data about public high schools in NYC from the past five years. It will be your job to explore the data, make sense of it, and come up with interesting insights and questions. For today, however, your task is to get to know the dataset, and to create some visualizations as you explore the data.
#
# First, let's import our necessary libraries. Pandas and Plotly.

# %%
# Import libraries here
import pandas as pd
import plotly.express as px

# %% [markdown]
# # Task 1: Explore the dataset
#
# ![](https://media.giphy.com/media/l4KibOaou932EC7Dy/giphy.gif)
#
# The dataset from the NYC department of education is named `schools.csv`, and is stored in your Datasets folder. Load the dataset into a DataFrame and complete the tasks below to start exploring!
#
# ## Data Dictionary
#
# The `schools` dataset contains the following information:
#
# - **school_name**: Name of the school
# - **total_enrollment**: Number of students enrolled
# - **percent_students_with_disabilities**: Percentage of students with disabilities
# - **percent_english_learners**: Percentage of students who speak English as a second language (ESL)
# - **percent_poverty**: Percentage of students who are below the poverty line

# %%
# Read the CSV file into a pandas DataFrame
nyc = pd.read_csv('datasets/schools.csv')

# %%
# Preview the first five rows
nyc.head()
# Out:
#                                          school_name  total_enrollment  \
# 0  47 The American Sign Language and English Seco...             176.6
# 1              A. Philip Randolph Campus High School            1394.8
# 2  A.C.E. Academy for Scholars at the Geraldine F...             469.8
# 3                        ACORN Community High School             391.0
# 4                        Abraham Lincoln High School            2161.8
#
#    percent_students_with_disabilities  percent_english_learners  \
# 0                               27.56                      6.12
# 1                               13.20                      9.94
# 2                               10.30                      8.18
# 3                               27.08                      4.16
# 4                               15.48                     15.88
#
#    percent_poverty
# 0            86.08
# 1            83.70
# 2            65.50
# 3            83.88
# 4            72.00

# %%
# preview the last five rows
nyc.tail()
# Out:
#                                        school_name  total_enrollment  \
# 1829               Young Women's Leadership School             479.6
# 1830   Young Women's Leadership School of Brooklyn             381.2
# 1831  Young Women's Leadership School of the Bronx             326.0
# 1832      Young Women's Leadership School, Astoria             566.4
# 1833       Young Women's Leadership School, Queens             558.6
#
#       percent_students_with_disabilities  percent_english_learners  \
# 1829                               18.60                      2.30
# 1830                               16.76                      4.30
# 1831                               17.64                      5.40
# 1832                               10.60                      3.62
# 1833                               13.60                      1.80
#
#       percent_poverty
# 1829            81.12
# 1830            78.26
# 1831            89.16
# 1832            83.60
# 1833            71.98

# %%
# List the columns of the DataFrame
nyc.columns
# Out:
# Index(['school_name', 'total_enrollment', 'percent_students_with_disabilities',
#        'percent_english_learners', 'percent_poverty'],
#       dtype='object')

# %%
# Examine the index of the DataFrame
nyc.index
# Out:
# RangeIndex(start=0, stop=1834, step=1)

# %% [markdown]
# According to the `index` how many **rows** are in the dataframe?
# There should be 1834 rows within the dataframe according to the 'index'.

# %%
# Examine the numbers of rows and columns 
# hint: what is the "shape" of the dataframe
nyc.shape
# Out:
# (1834, 5)

# %% [markdown]
# Does the number of rows and columns line up with what you have observed in your previous queries above? Why or Why not?
# According to the "shape" of the dataframe, there are 1834 rows and 5 columns. The number of rows does match the number of rows from the index and the number of columns also matches the 5 initial columns the problem gave me.

# %%
# View 15 randomly chosen rows
nyc.sample(15)
# Out:
#                                        school_name  total_enrollment  \
# 305                       Epic High School - North             236.5
# 1831  Young Women's Leadership School of the Bronx             326.0
# 787                            P.S. 001 The Bergen            1292.4
# 1065                         P.S. 120 Carlos Tapia             446.2
# 626                     Legacy College Preparatory             131.0
# 422           High School of Applied Communication             417.8
# 906                  P.S. 046 Albert V. Maniscalco             303.0
# 61                  Bard High School Early College             555.2
# 711                         Millennium Brooklyn HS             579.8
# 960                                 P.S. 068 Bronx             737.4
# 609              Kingsborough Early College School             599.8
# 966                        P.S. 070 Max Schoenfeld            1317.0
# 234            Concourse Village Elementary School             302.0
# ...

# %%
# Call .info() for column data types and other info
nyc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1834 entries, 0 to 1833
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   school_name                         1834 non-null   object
#  1   total_enrollment                    1834 non-null   float64
#  2   percent_students_with_disabilities  1834 non-null   float64
#  3   percent_english_learners            1834 non-null   float64
#  4   percent_poverty                     1834 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 71.8+ KB

# %%
# Call .describe() to view a statistical summary of the DataFrame
nyc.describe()
# Out:
#        total_enrollment  percent_students_with_disabilities  \
# count       1834.000000                         1834.000000
# mean         588.309481                           21.944242
# std          481.135549                           15.793045
# min           12.000000                            0.000000
# 25%          313.250000                           14.963750
# 50%          476.700000                           19.340000
# 75%          694.950000                           24.415000
# max         5591.800000                          100.000000
#
#        percent_english_learners  percent_poverty
# count               1834.000000      1834.000000
# mean                  13.284084        75.030873
# std                   13.986404        19.179663
# min                    0.000000         3.950000
# 25%                    4.120000        68.065000
# 50%                    9.070000        79.680000
# 75%                   17.785000        88.580000
# ...

# %% [markdown]
# When looking at statistical summaries of the data, pay attention to the mean and the median of each column. If these two values are super different, then there might be something you should look into.
#
# Do the mean and the median vary significantly in any of the columns?
#
# I assume that the median is the middle value of each column, so I will compare the mean and the 50% row together. According to my observation, the differences between all 4 columns' mean and median are not so high (within my own acceptable differences of 10 units). The largest difference is 5 units (for total enrollment and English learners) while the smallest difference is 2 units (for disabilities) which is fine in my book. Therefore, all of my data are pretty good to go.

# %% [markdown]
# #Task 2: Visually Explore the Data
#
# ![](https://media.giphy.com/media/wc5K9GF6Rort3DzFvi/giphy.gif)
#
# Now comes the even more fun part! We get to visualize the data to identify broad trends, and to spot relationships, if any, between the variables in the dataset.
#
# Remember: `px.histogram` is the workhorse of the Plotly library. It will be the most used function in your Python toolbox, especially as you're familiarizing yourself with a dataset.
#
# ### Task 2A. Create a histogram to view the distribution of total student enrollment in NYC public high schools.
#
# <span style='background :#FFF59E'>**Hint:** You'll need to use the `total_enrollment` column of your DataFrame!</span>

# %%
# Plot the data showing the total student enrollment
px.histogram(nyc, x = 'total_enrollment', title = 'The Distribution of Total Student Enrollment in NYC Public High Schools')

# %% [markdown]
# #### Answer the following questions:
# ---
#
# **1.** What kind of shape do you see in the data? For example, is it symmetric (bell-shaped), or do the values lump together on either the left or the right with a long tail of values on the other side?
#
#
# The values lump together on the left side of the graph and there are a little bit of values left on the right (form a long tail just like you said). If you look carefully, this data looks like a very long-tailed Godzilla loking up to the sky.

# %% [markdown]
# **2.** Are there any outliers in your data? Remember that outliers are values that are "far away" from a tyical value?
#
#
# There are quite a lot to be honest, but the one that really popped out to me is the furthest on the right, which contained the number of enrollments from 5550-5559.99, and there is only one of it. Whereaa other values even the other "outcast" values are from 4440-4449.99 and below, and they are relatively closer to this one.

# %% [markdown]
# **3.** Could these outliers (if any) skew the "average" value?
#
# I doubt it. Since these outliers does not have a lot of counts (5 at most), and with the total of 1834 entries, these little debris are not likely to affect the average value.

# %% [markdown]
# #### Task 2B. Create a histogram to view the distribution of the percentage of students with disabilities in schools.
#
# <span style='background :#FFF59E'>**Hint:** You'll need to use the `percent_students_with_disabilities` column of your DataFrame.</span>

# %%
# Plot the data showing the % of students with disabilities in schools
px.histogram(nyc, x = 'percent_students_with_disabilities', title = 'The Percentage of Students With Disabilities in NYC Public High Schools')

# %% [markdown]
# #### Answer the following questions:
# ---
#
# **1.** What kind of shape do you see in the data?
# I see a whale. You can see its little head on the very left, its big body still on the left, its long tail throughout the center and the right-end, and part of its flukes poking out of the water on the far right.

# %% [markdown]
# **2.** Are there any outliers in your data?
# Now this one does look a lot more distinguisable. The number of students with disabilites from 97-100% took a visibly big bump in the "outcast" values. Of course there are also more "outcasts" from 53% up to 100% scattering throughout the plot.

# %% [markdown]
# **3.** Could outliers indicate the existence of specialized schools for students with disabilities?
# Yes, they absolutely can. For reference, there are 48 schools that has the percentage of students with disabillites as 99%-100%, which indicates that almost, if not, every students in those schools are people with disabilities. This makes my day, since I'm glad there are still a lot of schools that open for people who really need help.

# %% [markdown]
# #### Task 2C. Create a histogram to view the distribution of the percentage of students who are learning English as a second language in NYC’s public high schools.
# <span style='background :#FFF59E'>**Hint:** Now you'll need to use the `percent_english_learners` column of your DataFrame. </span>

# %%
# Plot the data showing the % of students who are learning English as a second language in schools
px.histogram(nyc, x = 'percent_english_learners', title = 'The Percentage of English Learners in NYC Public High Schools')

# %% [markdown]
# #### Answer the following questions:
# ---
#
# **1.** What kind of shape do you see in the data?
#
# Similar to part 2B histogram but now, instead of the middle-ish left, all the majority data focus in the very left and then start decreasing the further the graph goes to the right. This one looks like a bunches of stairs.

# %% [markdown]
# **2.** Are there outliers?
#
# Yes, of course there are. The one that popped out to me is the 99-100% English learners, but even that outlier is not as far to other values compared to the previous 2 histogram. So I would say that the data for this graph is very well-distributed throughout.

# %% [markdown]
# **3.** What could those outliers indicate about those schools?
# Those schools who have above 40% English learners indicate that those must be school specialized for English-as-a-second-language speakers, which including me, an international students! The graph overall let me know that to study in the U.S., most schools will require English speaking skill. But some of the special schools aka the outliers will focus on helping international speakers familiar with the language, which is one again, makes my day since language is a huge barrier for a lot of people, including myself, when they first come to the U.S. or when they are too old to learn the language.

# %% [markdown]
# #### Task 2D. Create a histogram to view the distribution of the percentage of students whose families fall below the poverty line in NYC public high schools.
# <span style='background :#FFF59E'>**Hint:** For this one, you'll need to use the `percent_poverty` column of your DataFrame. </span>

# %%
# Plot the data showing the % of students whose families are below the poverty line in schools
px.histogram(nyc, x = 'percent_poverty', title = 'The Percentage of Students Living In Poverty in NYC Public High Schools')

# %% [markdown]
# #### Answer the following question:
# ---
#
# **1.** What can you say about the schools overall, if anything?
#
# This is quite shocking to me at first since the shape of the dataset is completely opposite compared to previous histograms, with most of the values lumb on the right rather than the left. However, thinking a little bit about it, it makes sense to me why the dataset looks that way. Since public education in the U.S. are free, most family who are poor but still want their children to have proper place to study send their kids to public schools. That will most likely explain why 60%-100% students in public schools in NYC are living in proverty. This doesn't make my day at all since as an international students, I thought that America is at least a little bit better in terms of economics than third-rate-country like mine. But then think again, I don't think that it reflects a lot in American society anyway since there are as much private schools as there are public schools in the U.S., unlike my country where most schools are public, so this data might not be able to show anything. Well, at least I can say that overall, schools are affordable in the U.S., which is a good thing. And that makes my day once again!

# %% [markdown]
# #### Task 2E: Create a scatter plot to see whether a relationship might exist between the percentage of low-income students in a school and the percentage of English learners in a school.
#
# The percentage of students who fall below the poverty line should be on the horizontal axis, and the percentage of English learners should be on the vertical axis.

# %%
# Create a scatter plot of percent_english_learners vs percent_poverty
px.scatter(nyc, x = 'percent_poverty', y = 'percent_english_learners', title = 'The Percentage of Students Living In Poverty in Relation to English Learners in NYC Public High Schools', color  = 'percent_students_with_disabilities')

# %%
# Create a scatter plot of percent_english_learners vs percent_poverty
px.scatter(nyc, x = 'percent_poverty', y = 'percent_english_learners', title = 'The Percentage of Students Living In Poverty in Relation to English Learners in NYC Public High Schools', color  = 'total_enrollment')

# %% [markdown]
# If there is a relationship, what policy recomendations can you make?
#
# I can first see that their relationship is a directly propotional one. This means that a school which a higher percentage of poverty also has a higher percatage of English learners. This can mean 2 things: either the schools are very generous and accept both poor and non-English speakers to their school or people who are poor are also the non-English speakers. I will say without any evidence to base on that the second case is most likely since not fluent in speaking English will just make it harder for securing a job in the U.S., thus making you poor. But that is just a baseless theory of mine. I also discovered that the number of enrolllments of these 2 types of people to NYC public schools are quite low, and not a lot of them are people with disability. But then I realized that the data above also shows the same results (in 2A and 2B) so this is kind of useless but I will state it here anyway. As for policy recomendations I can make, I might suggest the governers of NY to create policy that support international communities here, espeically immigrants who I think is most likely the English learners in this case (baseless assumption once again, I will need more data to work with to be honest). Creating more jobs opportunity for the minorities could also be a good idea here, though I doubt the governers will like it considered many said that immigrants steal Americans' jobs.

# %% [markdown]
# # Level Up
#
# ![](https://media.giphy.com/media/YL08285SCvrWbiEWX7/giphy.gif)
#
# Congratulations on completing the Milestone! In the last visualization, you created scatter plots to visually inspect whether a relationship might exist between variables.
#
# There is a way to **quantify** the relationship between *any* two variables! It is called **correlation**. Correlation ranges from -1 to 1.
#
# When the correlation between two variables is equal to 1, this means that there is a perfect relationship between them. Two variables that would be (almost!) perfectly correlated are `age` and `birth_year`. If you know someone's year of birth, you can predict their age. If you know their age, you can predict their birth year.
#
# When the correlation between two variables is equal to 0, this means that there is no relationship between two variables. For example, `shoe_size` and `favorite_color`. These two variables are not related in any meaningful way.
#
# A negative correlation means that an increase in one variable leads to a decrease in the other. For example, `sea_level` and `temperature`. As you climb a mountain, increasing your hight above sea level, it gets colder. The temperature decreases.
#
# Pandas offers a quick way to examine the correlation between variables at a single glance: the `.corr()` method applied to a DataFrame. The `.corr()` method will produce a table of correlation coefficients: each row/column intersection is the correlation between the variable named in the row and the variable named in the column.
#
# ---

# %% [markdown]
# ## Task 3: Correlated Variables
#
# #### Apply the .corr() method to your DataFrame containing the NYC Department of Education data.
#
# Examine the table and determine **which two variables have the strongest correlation, and how strong that correlation is.**
#
# Here's a rough guide to understanding correlation coefficients:
# - Correlation between 0 and 0.2 is considered to be non-existent to weak.
# - Correlation between 0.2 and 0.4 is considered weak.
# - Correlation between 0.4 and 0.6 is considered moderate.
# - Correlation between 0.6 and 0.8 is considered to be strong.
# - Correlation between 0.8 and 1 is considered to be very strong.
#
# <span style='background :#FFF59E'>**Note:** a variable will always be perfectly correlated with itself! So disregard the diagonal of your output when answering this question!</span>

# %%
# Apply the .corr() method to the dataframe
.corr()

# %% [markdown]
# *(Double-click to type your answer)*
