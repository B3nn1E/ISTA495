# %% [markdown]
# ![](https://www.nasa.gov/sites/default/files/thumbnails/image/nasa-logo-web-rgb.png)
#
# # Planetary Mystery
#
# Welcome to your first day as a data intern for NASA! As a fun exercise, all interns will be working to solve... a planetary mystery!
#
# The dataset you will be working on contains weather data for a planet in our solar system, but the identity of that planet is unknown. Your task is to use your data analytics chops to identify the mystery planet!
#
# As usual, you will begin by exploring your dataset.
#
# The dataset, provided by NASA, is called `planet_weather.csv`, and it contains the following information:
#
# - **terrestrial_date**: Date on planet Earth, captured as `yyyy-mm-dd`.
#
# - **sol**: number of elapsed planetary days since beginning measurement.
#
# - **ls**: solar longitude. 0: fall equinox. 90: winter solstice. 180: spring equinox. 270: summer solstice.
#
# - **month**: the month number on the mystery planet.
#
# - **min_temp**: the minimum temperature, in Celsius, during a single day.
#
# - **pressure**: atmospheric pressure, in Pascals.
#
# - **wind_speed**: average wind speed, in meters per second.
#
# - **atmo_opacity**: atmospheric opacity.

# %% [markdown]
# # Task 1: Data Inspection
#
# ![](https://media.giphy.com/media/pz7LNMYN2dj0hgKaHj/giphy.gif)

# %%
# import pandas and plotly express libraries
import pandas as pd
import plotly.express as px

# %%
# load planet_weather.csv data from datasets folder
planet = pd.read_csv('datasets/planet_weather.csv')

# %%
# preview the data
planet.sample(10)
# Out:
#         id terrestrial_date   sol   ls     month  min_temp  max_temp  pressure
# 863   1034       2015-09-11  1101   39  Month 02     -80.0     -23.0     891.0
# 1600   296       2013-07-08   327  347  Month 12     -74.0      -8.0     848.0
# 11    1884       2018-02-16  1966  130  Month 05     -77.0     -18.0     735.0
# 976    919       2015-05-16   986  342  Month 12     -74.0      -1.0     840.0
# 982    911       2015-05-10   980  339  Month 12     -73.0       1.0     840.0
# 1675   143       2013-04-17   248  302  Month 11     -70.0      -4.0     877.0
# 1757    51       2013-01-01   144  235  Month 08     -64.0       2.0     907.0
# 825   1070       2015-10-20  1139   57  Month 02     -80.0     -25.0     901.0
# 443   1448       2016-11-27  1532  268  Month 09     -72.0      -3.0     900.0
# 308   1588       2017-04-14  1667  349  Month 12     -76.0      -9.0     833.0

# %%
# How many rows and columns are there in the dataset?
planet.shape
#1894 rows and 8 columns.
# Out:
# (1894, 8)

# %%
# what are the names of all the columns?
planet.columns
#So the wind speed and atmo opacity never exist in the first place then?
# Out:
# Index(['id', 'terrestrial_date', 'sol', 'ls', 'month', 'min_temp', 'max_temp',
#        'pressure'],
#       dtype='object')

# %%
# What is the data type of each column?
planet.info()
#id, sol, and ls columns contained integer, while terrestrial_date and month contains object data(which I assume is also string data), and min_temp, max_temp, and pressure contain float data type.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1894 entries, 0 to 1893
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                1894 non-null   int64
#  1   terrestrial_date  1894 non-null   object
#  2   sol               1894 non-null   int64
#  3   ls                1894 non-null   int64
#  4   month             1894 non-null   object
#  5   min_temp          1867 non-null   float64
#  6   max_temp          1867 non-null   float64
#  7   pressure          1867 non-null   float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 118.5+ KB

# %%
# How many null values are there in each column?
#As you can see with the planet.info() above, only min_temp, max_temp, and pressure have null values. They all have 27 null values for each column.

# %%
# Provide a statistical summary of the DataFrame
planet.describe()
# Out:
#         id terrestrial_date   ls     month  min_temp  max_temp  pressure
# 0     1895       2018-02-27  135  Month 05     -77.0     -10.0     727.0
# 1     1893       2018-02-26  135  Month 05     -77.0     -10.0     728.0
# 2     1894       2018-02-25  134  Month 05     -76.0     -16.0     729.0
# 3     1892       2018-02-24  134  Month 05     -77.0     -13.0     729.0
# 4     1889       2018-02-23  133  Month 05     -78.0     -18.0     730.0
# ...    ...              ...  ...       ...       ...       ...       ...
# 1889    24       2012-08-18  156  Month 06     -76.0     -18.0     741.0
# 1890    13       2012-08-17  156  Month 06     -76.0     -11.0     740.0
# 1891     2       2012-08-16  155  Month 06     -75.0     -16.0     739.0
# 1892   232       2012-08-15  155  Month 06       NaN       NaN       NaN
# 1893     1       2012-08-07  150  Month 06       NaN       NaN       NaN
#
# [1894 rows x 7 columns]

# %% [markdown]
# # Task 2: Data Cleaning
#
# ![](https://media.giphy.com/media/l49JEBkw8tD64fbeE/giphy-downsized-large.gif)

# %%
# Looks like the wind speed sensor on the Rover was broken
# Delete wind_speed column, which is filled with null values
#Well I got an error because of course, there are no wind speed column here for me to remove in the first place.
#But if there is such column, I will write a code like this to remove wind speed: planet.drop(columns = 'wind_speed')

# %%
# How many unique values are there in the atmo_opacity column?
# hint: both .unique() and .value_counts() will work here
#Well, there are no atmo opacity here in the first place so I won't know. 
#But if I have to write a code to find out, it will be: planet.value_counts(). But if you want the number of unique values instead of what the unique values are, I think .nunique() will get the job done more efficient.

# %%
# The atmosphere sensors were faulty and did not capture accurate data
# Delete atmo_opacity column, which mostly contains identical values
#Again, there are no atmo opacity column, so...
#But if you want to remove it so much, the code I would use would be: planet.drop(columns = 'atmo_opacity')

# %% [markdown]
# # Task 3: Data Analysis & Visualization
#
# ![](https://media.giphy.com/media/1n8aGJBEXuW0M7ELrB/giphy.gif)

# %%
# How many months are there on this planet?
planet['month'].nunique()
# Out:
# 12

# %%
# What is the average min_temp for each month?
avg_min_temp = planet.groupby('month').agg({'min_temp':'mean'})

# %%
# Plot a bar chart of the average min_temp by month
px.bar(avg_min_temp, title = 'Average Minimum Temperature By Month on The Mysterious Planet')

# %% [markdown]
# Based on the minimum temperature, what is the coldest month? The warmest month?
# The coldest month should be Month 03, with the avg_min_temp as -83.3 degrees C. The warmest month should be Month 08, with the avg_min_temp as -68.4 degrees C.

# %%
# What is the average pressure for each month?
avg_pres = planet.groupby('month').agg({'pressure':'mean'})

# %%
# Create a bar chart of the average atmospheric pressure by month
px.bar(avg_pres, title = 'Average Pressure By Month on The Mysterious Planet')

# %%
# Plot a line chart of the daily atmospheric pressure by terrestrial date
# note: you do not need to modify the dataframe 
# use the original one you loaded at the beginning of the milestone.
pres = planet.groupby('terrestrial_date')
px.line(planet, x = 'terrestrial_date', y = 'pressure', title = 'Pressure By Terrestrial Date on The Mysterious Planet')

# %%
# Plot a line chart the daily minimum temp
# Did I accidentally delete something because I don't understand the question?
# note: you do not need to modify the dataframe 
# use the original one you loaded at the beginning of the milestone.
px.line(planet, x = 'terrestrial_date', y = 'min_temp', title = 'Minimum Temperature By Terrestrial Date on The Mysterious Planet')

# %% [markdown]
# ### Based on this information, approximately how many earth days are there in a year on this planet?
#
# <span style='background :#FFF59E'>**Note**: To get an approximate range for how long a "year" is on this planet, look at the plots of the atmospheric pressure and the temperatures by day. Use the visualizations to get a *rough estimate* between matching "peaks".</span>
#
# A year on this mysterious planet should be equal to 2 years on planet Earth roughly. I know this by using the last 2 graphs, since when a set of cycles start to repeating itself, it should tell me that one year has passed on that planet.

# %% [markdown]
# ### What is the identity of the planet?
#
# Go to [this wesbsite](https://spaceplace.nasa.gov/years-on-other-planets/en/) and see what planet this lines up with!
#
# Should be Mars, since the years on Mars did match up with my expectation and data. Using the temperature data above, I can also 85% sure that this planet is Mars since the temperature are not too hot like Mercury and Venus, but also not too cold like the ice and gas giants. If I got this wrong, I should just quit Astronomy major and do data analysis instead T-T.

# %% [markdown]
# ## Congratulations on making your first extra-terrestrial discovery!
#
# ![](https://media.giphy.com/media/5ndfKr0Nv92LkWrKpU/giphy.gif)

# %% [markdown]
# # Level Up
#
# ![](https://media.giphy.com/media/kjjRGpezebjaw/giphy.gif)
#
# Earlier in the milestone you investigated how many months were in our Mystery Planet. Unfortunately, the answer (12) was not very satisfying. This is because there is no standard calendar for Mars. When the data was collected, they used 12 "months" though each month is longer than a typical Earth month. Let's investigate!
#
# First, filter your dataset so that you are only looking at any `terrestrial_date` before 2014.
#
# <span style='background :#FFF59E'>**Note**: Since the `terrestrial_date` is a `string` data type, this is simply checking for all values that satisfy the condition `< '2014'` (<-- don't forget the quotes!) </span>

# %%
# filter to all values where terrestrial_date is before 2014
# store it in a new variable.
bef = planet[planet['terrestrial_date'] < '2014']
bef
# Out:
#        id terrestrial_date  sol   ls     month  min_temp  max_temp  pressure
# 1453  432       2013-12-31  499   69  Month 03     -84.0     -30.0     899.0
# 1454  424       2013-12-30  498   69  Month 03     -86.0     -28.0     901.0
# 1455  425       2013-12-29  497   69  Month 03     -86.0     -30.0     901.0
# 1456  428       2013-12-28  496   68  Month 03     -85.0     -26.0     901.0
# 1457  431       2013-12-27  495   68  Month 03     -86.0     -26.0     900.0
# ...   ...              ...  ...  ...       ...       ...       ...       ...
# 1889   24       2012-08-18   12  156  Month 06     -76.0     -18.0     741.0
# 1890   13       2012-08-17   11  156  Month 06     -76.0     -11.0     740.0
# 1891    2       2012-08-16   10  155  Month 06     -75.0     -16.0     739.0
# 1892  232       2012-08-15    9  155  Month 06       NaN       NaN       NaN
# 1893    1       2012-08-07    1  150  Month 06       NaN       NaN       NaN
#
# [441 rows x 8 columns]

# %% [markdown]
# <span style='background :#DDD5F3'>If done correctly, you will have a dataframe with `441` rows.</span>

# %% [markdown]
# Lastly, for each month in the dataframe, return both the `min` value and the `max` value of the `terrestrial_date` field.
#
# <span style='background :#FFF59E'>**Hint 1**: Use `.groupby()`</span>
#
# <span style='background :#FFF59E'>**Hint 2**: In the dictionary for your `.agg()` function, pass a `list` of values. e.g. `{col_to_check: [func1, func2]}`. Remember to use the appropriate values / variables from the dataframe and the desired functions.</span>

# %%
# For each month, calculate the min & max value of the terrestrial_date field.
bef.groupby('month').agg({'terrestrial_date':['max', 'min']})
# Out:
#          terrestrial_date
#                       max         min
# month
# Month 01       2013-10-02  2013-08-01
# Month 02       2013-12-08  2013-10-03
# Month 03       2013-12-31  2013-12-09
# Month 06       2012-09-29  2012-08-07
# Month 07       2012-11-19  2012-09-30
# Month 08       2013-01-07  2012-11-20
# Month 09       2013-02-23  2013-01-08
# Month 10       2013-04-12  2013-02-24
# Month 11       2013-06-04  2013-04-13
# Month 12       2013-07-31  2013-06-05

# %% [markdown]
# How many Earth days, roughly, are there in each "month" in the mystery planet? Does that lineup with what you expected now that you know the identity of the mystery planet?
#
# Besides some exception, in most cases, a month on the mystery planet is equal to 2 months on Earth. So if a month there is double a month on Earth, then its year should also be double Earth's year. And since the mysterious planet is Mars, I guess
